# %%
print(f""" ..................WLCOME TO BHARDWAJ DAIRY.................""")
print(f"""Hey my dear customer...I hope you are doing good today.......

                    """)
customer=input(".......sir do you wanna shop........yes/no....")
if customer.lower()=="yes":
 print("\nSure sir...just tell me what do you wanna buy..")
 print("Here is the list of itmes.... ")
 print("1 = 1 litre milk")
 print("2 = 1 kg curd")
 print("3 = 1 kg ghee")
 print("4 = 1 kg paneer")
 print("5 = 1 kg chaap")

 while True:
   choice=int(input(".....select the item you want to buy..."))
   if choice==1:
    print("...........you have selected milk. Pay ₹70.........")
   elif choice==2:
    print("........you have selected curd..Pay ₹100 .........")
   elif choice==3:
    print("........you have selected ghee.Pay ₹800.......")
   elif choice==4:
    print("........you have selected paneer.Pay ₹280......")
   elif choice==5:
    print("you have selected chaap.. Pay ₹100")
   else:
    print("soory sir you have entered a item not present in list....")

   again=input(" .....Sir do you want to shop again ?...yes/no... ").lower()
   if again=="no":
    print(".......Thank you for shopping....")
    break


else:
 print(f""".               ...You are not doing shopping today....
         .....oky sir thanks for your visit. Please come again......""")
# Out:
#  ..................WLCOME TO BHARDWAJ DAIRY.................
# Hey my dear customer...I hope you are doing good today.......
#
#
# .......sir do you wanna shop........yes/no....yes
#
# Sure sir...just tell me what do you wanna buy..
# Here is the list of itmes....
# 1 = 1 litre milk
# 2 = 1 kg curd
# 3 = 1 kg ghee
# 4 = 1 kg paneer
# 5 = 1 kg chaap
# .....select the item you want to buy...2
# ........you have selected curd..Pay ₹100 .........
#  .....Sir do you want to shop again ?...yes/no... yes
# .....select the item you want to buy...1
# ...........you have selected milk. Pay ₹70.........
#  .....Sir do you want to shop again ?...yes/no... no
# .......Thank you for shopping....
