# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
my_tuple=(1,2,3,4,5)
print("tuples: ",my_tuple)
# Out:
# tuples:  (1, 2, 3, 4, 5)

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
my_tuple=(1,3,5.4,4.5,"harsh","hunny",True)
print("different types of tuples...",my_tuple)
# Out:
# different types of tuples... (1, 3, 5.4, 4.5, 'harsh', 'hunny', True)

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
my_tuple=("hanny","hunny","harsh","himanshu")
print("the lenghts of a tuple: ",len(my_tuple))
# Out:
# the lenghts of a tuple:  4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
my_tuple=(1,2,3,4,5,6)
print("last element of tuple :",my_tuple[-1])
# Out:
# last element of tuple : 6

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
my_tuplee=(1,2,3,4,5)
print(2 in my_tuplee)
# Out:
# True

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
t=(1,2,3,4,5,6)
print(list(t))
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
my_list=[1,2,3,4,5,6]
print(tuple(my_list))
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
my_tuple=(1,2,3,4,5,5,5,5,6)
print(my_tuple.count(5))
# Out:
# 4

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
my_tuple=(1,2,3,4,5,6)
print(my_tuple.index(5))
# Out:
# 4

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
my_tuple(1,2,3,4,5,6)
my_tuple[0]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-44909045.py in <cell line: 0>()
# ----> 1 my_tuple(1,2,3,4,5,6)
#       2 my_tuple[0]=5
#
# TypeError: 'tuple' object is not callable
